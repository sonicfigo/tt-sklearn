# %%
# coding=utf-8
"""
l6_1.py的一小部分，在此图形展示
"""
import sys

# for ipython import py
sys.path.append('/Users/figo/pcharm/ml/try_sklearn/kevin_markham/l6')

import seaborn as sns
import matplotlib.pyplot as plt

from l6_1 import load_data

% matplotlib inline

# beautiful seaborn
data = load_data()
sns.pairplot(data, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales',
             size=4, aspect=0.7, kind='reg')

# %%
data2 = load_data()
data2.plot()
plt.show()
# Out:
# (200, 4)
