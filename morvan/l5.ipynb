# %%
# coding=utf-8
"""
加载已有数据
或
自己生成数据，用于学习
"""
from sklearn import datasets
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

loaded_data = datasets.load_boston()
X = loaded_data.data
y = loaded_data.target

model = LinearRegression()
model.fit(X, y)

print('预测值(准确率不高):', model.predict(X[:4, :]))
print('真实值:', y[:4])

# 创造一些数据，以供学习:  100样例，1个特性， 一个输出，一个噪音, 改为noise=10后更加离散
X, y = datasets.make_regression(n_samples=100, n_features=1, n_targets=1, noise=10)
plt.scatter(X, y)
plt.show()
# Out:
# ('\xe9\xa2\x84\xe6\xb5\x8b\xe5\x80\xbc:', array([ 30.00821269,  25.0298606 ,  30.5702317 ,  28.60814055]))
# ('\xe7\x9c\x9f\xe5\xae\x9e\xe5\x80\xbc:', array([ 24. ,  21.6,  34.7,  33.4]))
